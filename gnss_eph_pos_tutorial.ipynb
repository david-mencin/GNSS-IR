# %%
# %pip install altair plotly polars vegafusion vl-convert-python
# Out:
# Requirement already satisfied: altair in /srv/conda/envs/notebook/lib/python3.12/site-packages (5.5.0)
# Requirement already satisfied: plotly in /srv/conda/envs/notebook/lib/python3.12/site-packages (6.3.1)
# Requirement already satisfied: polars in /srv/conda/envs/notebook/lib/python3.12/site-packages (1.34.0)
# Requirement already satisfied: vegafusion in /srv/conda/envs/notebook/lib/python3.12/site-packages (2.0.3)
# Requirement already satisfied: vl-convert-python in /srv/conda/envs/notebook/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: jinja2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from altair) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from altair) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from altair) (2.9.0)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.12/site-packages (from altair) (24.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from altair) (4.12.2)
# Requirement already satisfied: polars-runtime-32==1.34.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from polars) (1.34.0)
# Requirement already satisfied: arro3-core in /srv/conda/envs/notebook/lib/python3.12/site-packages (from vegafusion) (0.4.5)
# Requirement already satisfied: attrs>=22.2.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (0.36.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (0.22.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from jinja2->altair) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # GNSS Satellite Ephemeris Positions Tutorial
#
# This tutorial demonstrates how to retrieve GNSS satellite positions using the EarthScope SDK.

# %%
import datetime as dt
import math

import altair as alt
import numpy as np
import plotly.colors as pcolors
import plotly.graph_objects as go
import plotly.io as pio
import polars as pl

from earthscope_sdk import AsyncEarthScopeClient
from earthscope_sdk.client.data_access.models import (
    FloatFilter,
    GeodeticCoordinate,
    SatelliteSystem,
)

alt.data_transformers.enable("vegafusion")  # Enable rust backend for altair
pio.renderers.default = "notebook"  # required for plotly to render in jupyterbook

es = AsyncEarthScopeClient()

# %% [markdown]
# ## Retrieving Satellite Positions
#
# You can easily retrieve satellite positions in an Earth-Centered, Earth-Fixed reference frame using the SDK as demonstrated in the following cell.
#
# Choose your desired time range, constellation(s), satellite(s) (optional), and desired sample period.

# %%
start_datetime = dt.datetime(2025, 9, 22)
end_datetime = dt.datetime(2025, 9, 23)
system = ["G", "R", "E", "C", "S"]

table = await es.data.gnss_ephemeris_positions(
    start_datetime=start_datetime,
    end_datetime=end_datetime,
    field=["x", "y", "z"],
    system=system,
    sample_interval=dt.timedelta(minutes=5),
).fetch()
df = pl.from_arrow(table)
df.sort("timestamp")
# Out:
# shape: (31_422, 6)
# ┌─────────────────────────┬────────┬───────────┬───────────┬───────────┬────────────┐
# │ timestamp               ┆ system ┆ satellite ┆ x         ┆ y         ┆ z          │
# │ ---                     ┆ ---    ┆ ---       ┆ ---       ┆ ---       ┆ ---        │
# │ datetime[ms, UTC]       ┆ str    ┆ i8        ┆ f64       ┆ f64       ┆ f64        │
# ╞═════════════════════════╪════════╪═══════════╪═══════════╪═══════════╪════════════╡
# │ 2025-09-22 00:00:00 UTC ┆ G      ┆ 31        ┆ 2.4962e7  ┆ -9.4918e6 ┆ 1.1702e6   │
# │ 2025-09-22 00:00:00 UTC ┆ G      ┆ 2         ┆ 1.0679e7  ┆ -1.7478e7 ┆ -1.6211e7  │
# │ 2025-09-22 00:00:00 UTC ┆ G      ┆ 16        ┆ 1.0966e7  ┆ -1.0362e7 ┆ 2.1494e7   │
# │ 2025-09-22 00:00:00 UTC ┆ G      ┆ 21        ┆ -1.6391e7 ┆ 4.6520e6  ┆ 2.0375e7   │
# │ 2025-09-22 00:00:00 UTC ┆ G      ┆ 13        ┆ -1.3350e7 ┆ 2.0741e7  ┆ 9.2407e6   │
# │ …                       ┆ …      ┆ …         ┆ …         ┆ …         ┆ …          │
# │ 2025-09-23 00:00:00 UTC ┆ E      ┆ 10        ┆ 2.0025e7  ┆ 8.5705e6  ┆ 2.0049e7   │
# │ 2025-09-23 00:00:00 UTC ┆ E      ┆ 21        ┆ -1.7422e7 ┆ 5.1905e6  ┆ -2.3357e7  │
# │ 2025-09-23 00:00:00 UTC ┆ E      ┆ 25        ┆ 1.7758e7  ┆ -4.6943e6 ┆ 2.3221e7   │
# │ 2025-09-23 00:00:00 UTC ┆ E      ┆ 29        ┆ -1.7563e7 ┆ 1.6301e7  ┆ 1.7372e7   │
# │ 2025-09-23 00:00:00 UTC ┆ S      ┆ 28        ┆ 5.1408e6  ┆ 4.1865e7  ┆ -23322.448 │
# └─────────────────────────┴────────┴───────────┴───────────┴───────────┴────────────┘

# %% [markdown]
# ### Plotting Satellite Positions
#
# The following cell defines a function that uses `plotly` to plot the satellite orbits in an Earth-Centered, Earth-Fixed (ECEF) reference frame.

# %%
def plot_satellite_positions(df: pl.DataFrame, system: SatelliteSystem):
    """
    Plot satellite positions in ECEF reference frame with an earth-sized ellipsoid.
    """
    # Group coordinates by svid
    coords = df.filter(pl.col("system") == system).to_dicts()
    coords_by_svid = {}
    for coord in coords:
        svid = coord["satellite"]
        if svid not in coords_by_svid:
            coords_by_svid[svid] = {"x": [], "y": [], "z": [], "timestamp": []}
        coords_by_svid[svid]["x"].append(coord["x"])
        coords_by_svid[svid]["y"].append(coord["y"])
        coords_by_svid[svid]["z"].append(coord["z"])
        coords_by_svid[svid]["timestamp"].append(coord["timestamp"])

    # Earth's radii in meters (WGS84)
    equatorial_radius = 6378137.0
    polar_radius = 6356752.3

    # Create the Earth's ellipsoid wireframe
    u = np.linspace(0, 2 * np.pi, 100)
    v = np.linspace(0, np.pi, 100)
    x_earth = equatorial_radius * np.outer(np.cos(u), np.sin(v))
    y_earth = equatorial_radius * np.outer(np.sin(u), np.sin(v))
    z_earth = polar_radius * np.outer(np.ones(np.size(u)), np.cos(v))

    earth_wireframe = go.Surface(
        x=x_earth,
        y=y_earth,
        z=z_earth,
        colorscale="Blues",
        showscale=False,
        opacity=0.2,
        name="Earth",
    )

    # Create a 3D scatter plot for each satellite trajectory
    satellite_traces = []
    colors = pcolors.qualitative.Plotly
    for i, (svid, coords_list) in enumerate(coords_by_svid.items()):
        satellite_traces.append(
            go.Scatter3d(
                x=coords_list["x"],
                y=coords_list["y"],
                z=coords_list["z"],
                mode="lines",
                text=coords_list["timestamp"],
                hoverinfo="all",
                line=dict(color=colors[i % len(colors)], width=2),
                name=f"SVID {svid}",
            )
        )

    fig = go.Figure(data=[earth_wireframe] + satellite_traces)

    # Update the layout for a cleaner look
    fig.update_layout(
        title="Satellite XYZ Coordinates (System: {})".format(system),
        scene=dict(
            xaxis_title="X Coordinate",
            yaxis_title="Y Coordinate",
            zaxis_title="Z Coordinate",
            aspectmode="data",
        ),
        margin=dict(r=20, b=10, l=10, t=40),
    )

    return fig

# %%
fig = plot_satellite_positions(df, "C")
fig.show(height=1500)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="f2a54b58-e9a7-4aaf-b14f-a398fbf2d228" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f2a54b58-e9a7-4aaf-b14f-a398fbf2d228")) {                    Plotly.newPlot(                        "f2a54b58-e9a7-4aaf-b14f-a398fbf2d228",                        [{"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"name":"Earth","opacity":0.2,"showscale":false,"x":{"dtype":"f8","bdata":"AAAAAAAAAACXVkXa6LMIQRIBasu5sBhBG9kJ75CAIkEXqiwGAKQoQXR+cxkVwS5BdOcrXR5rMkFuUrrC8nA1QSzy\u002fkRAcThBqwhL2EBrO0E1B7QQMF4+QcygWqqlpEBBHbSsB+kVQkFSbe\u002fwgoJDQYEDZWoV6kRBD5gsxENMRkFVjiaysqhHQUIvfWMI\u002f0hBGYjLmexOSkFgjNy\u002fCJhLQRqe\u002fP8H2kxBgrvXWZcUTkEWr963ZUdPQSnfFgISOVBBz7l3nkLKUEE1IRtEH1dRQbTzo6OD31FB2MWqlExjUkHU680eWOJSQbskc4KFXFNBsKU4QbXRU0EJWBMmyUFUQZgyGE2krFRBZKzuKisSVUFNXeqTQ3JVQRr4ycLUzFVB0+AZX8chVkH+uTiDBXFWQaJb\u002fMF6ulZBtL\u002f1KxT+VkFPiFJUwDtXQcDdWlVvc1dB+XuK1BKlV0H24EMGntBXQfKnHLEF9ldBzzfCMEAVWEG2BXZ4RS5YQfDHIBUPQVhBFBD8LphNWEHM3tGK3VNYQcze0YrdU1hBFBD8LphNWEHwxyAVD0FYQbYFdnhFLlhBzzfCMEAVWEHypxyxBfZXQfbgQwae0FdB+XuK1BKlV0HA3VpVb3NXQU+IUlTAO1dBtL\u002f1KxT+VkGjW\u002fzBerpWQf25OIMFcVZB1OAZX8chVkEa+MnC1MxVQU1d6pNDclVBY6zuKisSVUGXMhhNpKxUQQlYEybJQVRBsaU4QbXRU0G6JHOChVxTQdTrzR5Y4lJB2MWqlExjUkG086Ojg99RQTQhG0QfV1FBzrl3nkLKUEEp3xYCEjlQQRmv3rdlR09BgLvXWZcUTkEanvz\u002fB9pMQWGM3L8ImEtBGIjLmexOSkFCL31jCP9IQVWOJrKyqEdBEZgsxENMRkF+A2VqFepEQVBt7\u002fCCgkNBHbSsB+kVQkHPoFqqpaRAQTAHtBAwXj5BqwhL2EBrO0Eu8v5EQHE4QXNSusLycDVBcecrXR5rMkF0fnMZFcEuQR2qLAYApChBDtkJ75CAIkEGAWrLubAYQZlWRdroswhBrZ+P95jWCj4AAAAAAAAAAOcG8XAtpwhBF6osBgCkGEEOagKoB3ciQblnBtBMlyhB+j4\u002fOjuxLkGcowokoGEyQfRjgrLlZTVBVvfvNqdkOEEDyrcLH107QTMtLCqJTj5B03iKrhGcQEGOg1+5lgxCQW6cQ7d0eENBOaHp3E3fREFLTjaqxUBGQc5FGAKBnEdBN5IEQibySEE3lhFZXUFKQWR1qt7PiUtBmRvVKCnLTEFYJQViFgVOQdwIdp5GN09BfH+DeLUwUEGgpck\u002fm8FQQYHSYEsvTlFB0tKiXk3WUUH4Ikdj0llSQbJMbnKc2FJB8A5f3YpSU0E2D\...\u002fM1fsdTQe8OX92KUlNBskxucpzYUkH4Ikdj0llSQdPSol5N1lFBf9JgSy9OUUGfpck\u002fm8FQQXx\\u002ff6mKQfPkGi4MSSXoJAQbYDU2qp8EFBzVnRZ1RaQ0HbxRJRAr9EQZaWGzVXHkZBHKnUg\u002fh3R0FqlGMljctIQUzZIZG9GEpBMCst5DNfS0H5AIv3m55MQda42XWj1k1BwLeJ8PkGT0EEhkx6qBdQQXEdZg+up1BBP4Gvl2gzUUGf\...\u002f6TDrS6UUE9ga+XaDNRQXEdZg+up1BBBIZMeqgXUEHDt4nw+QZPQdS42XWj1k1B+QCL95ueTEEyKy3kM19LQUvZIZG9GEpBapRjJY3LSEEcqdSD+HdHQZiWGzVXHkZB2MUSUQK\u002fREHLWdFnVFpDQbYDU2qp8EFBpeDEkl6CQEE29\u002fqYpB8+Qe5MTDfIMjtBpN43Cek+OEEYFx3myUQ1QblDx0EvRTJBfrOT872BLkEz8v5EQHEoQY+ncad1WiJBU86i1N99GEG1StNUCIEIQUcjO4FSnwo+AAAAAAAAAADNTALYoEEIQUA60YOAPhhBHhzGYPgqIkHwhtmdATIoQcaWbDnOMi5BHLSsB+kVMkG7wpN+wQ01QaND0qMsADhBVQ7v\u002f2fsOkHbuLGzstE9QXAH7dSmV0BB6r0w5D3CQUHL2pwQQShDQZkLPhFUiURB7J\u002f+4hvlRUFZWRzgPjtHQY4vRNdki0hB3BNOIjfVSUHd15K8YBhLQXN11liOVExB3hHBdm6JTUH+MuF3sbZOQV28MbQJ3E9B3zQPx5V8UEEczwDD5gZRQdNAiybUjFFBEkXtazsOUkFs2uw3+4pSQaFrcGLzAlNBUc3I\u002fgR2U0GZ7aljEuRTQasn0DL\u002fTFRBx0JQYLCwVEESOpA5DA9VQT0B52v6Z1VB1JDhCmS7VUGAnCuWMwlWQUVtGv9UUVZBGnLYrbWTVkGBMTCGRNBWQQRg9evxBldBdPgKx683V0FlTAWHcWJXQTcdZyYsh1dB5Od4LdalV0EfqLm0Z75XQbtx6Gba0FdB5Fmmgi ...

# %% [markdown]
# ## Elevation and Azimuth
#
# You can also provide a reference point to compute the elevation and azimuth to each satellite at a given sample interval.
#
# Optionally, filters may be provided for elevation and azimuth.
#
# In the following examples, we use elevation and azimuth to visualize the SNR in multiple ways.

# %% [markdown]
# ### Joining Elevation and Azimuth with Observations
#
# With satellite elevation and azimuth, we can analyze observations in a spatial context.
#
# First, let's query the desired GNSS observations:

# %%
system = "G"
satellite = [5, 7, 11, 13]
station_name = "P041"
station_location = GeodeticCoordinate(
    latitude=39.7392358,
    longitude=-104.990251,
    height=1000,
)

obs_df = await es.data.gnss_observations(
    start_datetime=start_datetime,
    end_datetime=end_datetime,
    system=system,
    satellite=satellite,
    station_name=station_name,
    session_name="A",
    obs_code="1C",
    field="snr",
).fetch()
obs_df = pl.from_arrow(obs_df)
obs_df.sort("timestamp")
# Out:
# shape: (7_842, 6)
# ┌─────────────────────────┬───────────┬──────────┬───────┬────────┬───────────┐
# │ timestamp               ┆ satellite ┆ obs_code ┆ snr   ┆ system ┆ igs       │
# │ ---                     ┆ ---       ┆ ---      ┆ ---   ┆ ---    ┆ ---       │
# │ datetime[ms, UTC]       ┆ u8        ┆ str      ┆ f32   ┆ str    ┆ str       │
# ╞═════════════════════════╪═══════════╪══════════╪═══════╪════════╪═══════════╡
# │ 2025-09-22 00:00:00 UTC ┆ 7         ┆ 1C       ┆ 48.0  ┆ G      ┆ P04100USA │
# │ 2025-09-22 00:00:15 UTC ┆ 7         ┆ 1C       ┆ 48.0  ┆ G      ┆ P04100USA │
# │ 2025-09-22 00:00:30 UTC ┆ 7         ┆ 1C       ┆ 47.75 ┆ G      ┆ P04100USA │
# │ 2025-09-22 00:00:45 UTC ┆ 7         ┆ 1C       ┆ 47.75 ┆ G      ┆ P04100USA │
# │ 2025-09-22 00:01:00 UTC ┆ 7         ┆ 1C       ┆ 47.75 ┆ G      ┆ P04100USA │
# │ …                       ┆ …         ┆ …        ┆ …     ┆ …      ┆ …         │
# │ 2025-09-22 23:58:45 UTC ┆ 7         ┆ 1C       ┆ 48.0  ┆ G      ┆ P04100USA │
# │ 2025-09-22 23:59:00 UTC ┆ 7         ┆ 1C       ┆ 48.25 ┆ G      ┆ P04100USA │
# │ 2025-09-22 23:59:15 UTC ┆ 7         ┆ 1C       ┆ 48.5  ┆ G      ┆ P04100USA │
# │ 2025-09-22 23:59:30 UTC ┆ 7         ┆ 1C       ┆ 48.0  ┆ G      ┆ P04100USA │
# │ 2025-09-22 23:59:45 UTC ┆ 7         ┆ 1C       ┆ 48.25 ┆ G      ┆ P04100USA │
# └─────────────────────────┴───────────┴──────────┴───────┴────────┴───────────┘

# %% [markdown]
# Next, we retrieve satellite elevation and azimuth for the same system and satellites.

# %%
table = await es.data.gnss_ephemeris_positions(
    start_datetime=start_datetime,
    end_datetime=end_datetime,
    field=["elevation", "azimuth"],
    system=system,
    satellite=satellite,
    reference_point=station_location,
    sample_interval=dt.timedelta(seconds=15),
    elevation_filter=FloatFilter(min=0),
).fetch()
azel_df = pl.from_arrow(table)
azel_df.sort("timestamp")
# Out:
# shape: (8_019, 5)
# ┌─────────────────────────┬────────┬───────────┬───────────┬────────────┐
# │ timestamp               ┆ system ┆ satellite ┆ elevation ┆ azimuth    │
# │ ---                     ┆ ---    ┆ ---       ┆ ---       ┆ ---        │
# │ datetime[ms, UTC]       ┆ str    ┆ i8        ┆ f32       ┆ f32        │
# ╞═════════════════════════╪════════╪═══════════╪═══════════╪════════════╡
# │ 2025-09-22 00:00:00 UTC ┆ G      ┆ 7         ┆ 48.274212 ┆ 298.52771  │
# │ 2025-09-22 00:00:15 UTC ┆ G      ┆ 7         ┆ 48.352226 ┆ 298.636108 │
# │ 2025-09-22 00:00:30 UTC ┆ G      ┆ 7         ┆ 48.43026  ┆ 298.744598 │
# │ 2025-09-22 00:00:45 UTC ┆ G      ┆ 7         ┆ 48.508312 ┆ 298.853241 │
# │ 2025-09-22 00:01:00 UTC ┆ G      ┆ 7         ┆ 48.58638  ┆ 298.962006 │
# │ …                       ┆ …      ┆ …         ┆ …         ┆ …          │
# │ 2025-09-22 23:59:00 UTC ┆ G      ┆ 7         ┆ 49.233974 ┆ 299.867706 │
# │ 2025-09-22 23:59:15 UTC ┆ G      ┆ 7         ┆ 49.312218 ┆ 299.977661 │
# │ 2025-09-22 23:59:30 UTC ┆ G      ┆ 7         ┆ 49.39048  ┆ 300.087738 │
# │ 2025-09-22 23:59:45 UTC ┆ G      ┆ 7         ┆ 49.468758 ┆ 300.197968 │
# │ 2025-09-23 00:00:00 UTC ┆ G      ┆ 7         ┆ 49.547054 ┆ 300.308319 │
# └─────────────────────────┴────────┴───────────┴───────────┴────────────┘

# %% [markdown]
# Finally, we join the two together and visualize it in different ways.

# %%
join_df = obs_df.join(
    azel_df,
    on=["timestamp", "satellite", "system"],
    how="inner",
)
join_df.sort("timestamp")
# Out:
# shape: (7_810, 8)
# ┌─────────────────────┬───────────┬──────────┬───────┬────────┬───────────┬───────────┬────────────┐
# │ timestamp           ┆ satellite ┆ obs_code ┆ snr   ┆ system ┆ igs       ┆ elevation ┆ azimuth    │
# │ ---                 ┆ ---       ┆ ---      ┆ ---   ┆ ---    ┆ ---       ┆ ---       ┆ ---        │
# │ datetime[ms, UTC]   ┆ u8        ┆ str      ┆ f32   ┆ str    ┆ str       ┆ f32       ┆ f32        │
# ╞═════════════════════╪═══════════╪══════════╪═══════╪════════╪═══════════╪═══════════╪════════════╡
# │ 2025-09-22 00:00:00 ┆ 7         ┆ 1C       ┆ 48.0  ┆ G      ┆ P04100USA ┆ 48.274212 ┆ 298.52771  │
# │ UTC                 ┆           ┆          ┆       ┆        ┆           ┆           ┆            │
# │ 2025-09-22 00:00:15 ┆ 7         ┆ 1C       ┆ 48.0  ┆ G      ┆ P04100USA ┆ 48.352226 ┆ 298.636108 │
# │ UTC                 ┆           ┆          ┆       ┆        ┆           ┆           ┆            │
# │ 2025-09-22 00:00:30 ┆ 7         ┆ 1C       ┆ 47.75 ┆ G      ┆ P04100USA ┆ 48.43026  ┆ 298.744598 │
# │ UTC                 ┆           ┆          ┆       ┆        ┆           ┆           ┆            │
# │ 2025-09-22 00:00:45 ┆ 7         ┆ 1C       ┆ 47.75 ┆ G      ┆ P04100USA ┆ 48.508312 ┆ 298.853241 │
# │ UTC                 ┆           ┆          ┆       ┆        ┆           ┆           ┆            │
# │ 2025-09-22 00:01:00 ┆ 7         ┆ 1C       ┆ 47.75 ┆ G      ┆ P04100USA ┆ 48.58638  ┆ 298.962006 │
# │ UTC                 ┆           ┆          ┆       ┆        ┆           ┆           ┆            │
# │ …                   ┆ …         ┆ …        ┆ …     ┆ …      ┆ …         ┆ …         ┆ …          │
# │ 2025-09-22 23:58:45 ┆ 7         ┆ 1C       ┆ 48.0  ┆ G      ┆ P04100USA ┆ 49.15575  ┆ 299.757874 │
# │ UTC                 ┆           ┆          ┆       ┆        ┆           ┆           ┆            │
# │ 2025-09-22 23:59:00 ┆ 7         ┆ 1C       ┆ 48.25 ┆ G      ┆ P04100USA ┆ 49.233974 ┆ 299.867706 │
# │ UTC                 ┆           ┆          ┆       ┆        ┆           ┆           ┆            │
# │ 2025-09-22 23:59:15 ┆ 7         ┆ 1C       ┆ 48.5  ┆ G      ┆ P04100USA ┆ 49.312218 ┆ 299.977661 │
# │ UTC                 ┆           ┆          ┆       ┆        ┆           ┆           ┆            │
# │ 2025-09-22 23:59:30 ┆ 7         ┆ 1C       ┆ 48.0  ┆ G      ┆ P04100USA ┆ 49.39048  ┆ 300.087738 │
# │ UTC                 ┆           ┆          ┆       ┆        ┆           ┆           ┆            │
# │ 2025-09-22 23:59:45 ┆ 7         ┆ 1C       ┆ 48.25 ┆ G      ┆ P04100USA ┆ 49.468758 ┆ 300.197968 │
# │ UTC                 ┆           ┆          ┆       ┆        ┆           ┆           ┆            │
# └─────────────────────┴───────────┴──────────┴───────┴────────┴───────────┴───────────┴────────────┘

# %% [markdown]
# ### Elevation vs. SNR

# %%
join_df.filter(pl.col("elevation") < 30).with_columns(
    pl.col("satellite").cast(pl.Utf8)
).plot.point(x="elevation", y="snr", color="satellite").properties(
    title=f"{station_name}: Mean SNR by Elevation and Azimuth",
    width=650,
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Polar Heatmap

# %%
# The main heatmap of SNR by elevation and azimuth
heatmap = (
    alt.Chart(join_df)
    .mark_arc(tooltip=True)
    .encode(
        alt.Theta(
            "azimuth:Q",
            bin=alt.Bin(maxbins=180),
            scale=alt.Scale(domain=[0, 360]),
        ),
        alt.Radius(
            "elevation:Q",
            bin=alt.Bin(step=2),
            scale=alt.Scale(domain=[90, 0]),  # Zenith at center
        ),
        alt.Color("mean(snr):Q", title="Mean SNR", scale=alt.Scale(scheme="viridis")),
    )
)

# --- Axis Layers ---

# Radial axis (for elevation)
elevation_rings_df = pl.DataFrame({"elevation": [75, 60, 45, 30, 15, 0]})
radius_scale = alt.Scale(domain=[90, 0])

# Concentric circles as gridlines
elevation_rings = (
    alt.Chart(elevation_rings_df)
    .mark_arc(fill=None, stroke="lightgrey", strokeDash=[2, 2])
    .encode(
        theta=alt.value(2 * math.pi),
        radius=alt.Radius("elevation:Q", scale=radius_scale).stack(False),
        detail="elevation:Q",  # Draw a separate arc for each elevation value
    )
)

# Text labels for elevation
elevation_labels = (
    alt.Chart(elevation_rings_df)
    .mark_text(color="grey", align="right", size=14)
    .encode(
        text=alt.Text("elevation:Q", format=".0f"),
        theta=alt.value(math.pi / 12),  # Place labels at 15 degrees
        radius=alt.Radius("elevation:Q", scale=radius_scale),
        detail="elevation:Q",  # Ensure a label for each elevation value
    )
)

# Azimuth axis labels
azimuth_labels_df = pl.DataFrame(
    {
        "azimuth": [0, 30, 60, 90, 120, 150, 180, 210, 240, 270, 300, 330],
        "label": [
            "N",
            "30°",
            "60°",
            "E",
            "120°",
            "150°",
            "S",
            "210°",
            "240°",
            "W",
            "300°",
            "330°",
        ],
    }
)

azimuth_labels = (
    alt.Chart(azimuth_labels_df)
    .mark_text(
        radius=265,  # Place labels just outside the plot
        color="grey",
        size=12,
    )
    .encode(text="label:N", theta=alt.Theta("azimuth:Q"))
)

# Layer all the charts
chart = (
    alt.layer(heatmap, elevation_rings, elevation_labels, azimuth_labels)
    .properties(
        title=f"{station_name}: Mean SNR by Elevation and Azimuth",
        width=500,
        height=500,
    )
    .configure_title(fontSize=16)
)

chart
# Out:
# alt.LayerChart(...)
